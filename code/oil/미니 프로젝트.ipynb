# %%
import numpy as np
import pandas as pd

# %%
oil.sample(10)
# Out:
#                 ID COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  \
# 5651   TRAIN_05651          COMPONENT1         1000  2013
# 11436  TRAIN_11436          COMPONENT1         3106  2016
# 12042  TRAIN_12042          COMPONENT3         1345  2011
# 909    TRAIN_00909          COMPONENT3         3067  2012
# 6548   TRAIN_06548          COMPONENT1         2022  2009
# 10682  TRAIN_10682          COMPONENT3         1914  2010
# 4953   TRAIN_04953          COMPONENT3         6321  2010
# 9046   TRAIN_09046          COMPONENT3         4875  2012
# 6433   TRAIN_06433          COMPONENT4         3473  2014
# 178    TRAIN_00178          COMPONENT1         2740  2019
#
#        SAMPLE_TRANSFER_DAY  ANONYMOUS_2  AG  AL    B  BA  ...  U25  U20  U14  \
# 5651                     3          200   0   5  131   0  ...  NaN  NaN  NaN
# 11436                    8          200   0   1    6   0  ...  NaN  NaN  NaN
# 12042                   14          200   0   4    4   0  ...  NaN  NaN  NaN
# ...

# %%
oil.isna().sum()
# Out:
# ID                         0
# COMPONENT_ARBITRARY        0
# ANONYMOUS_1                0
# YEAR                       0
# SAMPLE_TRANSFER_DAY        0
# ANONYMOUS_2                0
# AG                         0
# AL                         0
# B                          0
# BA                         0
# BE                         0
# CA                         0
# CD                      1394
# CO                         0
# CR                         0
# CU                         0
# FH2O                   10205
# FNOX                   10205
# FOPTIMETHGLY           10205
# FOXID                  10205
# FSO4                   10205
# FTBN                   10205
# FE                         0
# FUEL                   10205
# H2O                        0
# K                       2299
# LI                         0
# MG                         0
# MN                         0
# MO                         0
# NA                         0
# NI                         0
# ...

# %%
oil = pd.read_csv('C:/k_digital/source/data/open/train.csv')
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14095 entries, 0 to 14094
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   14095 non-null  object
#  1   COMPONENT_ARBITRARY  14095 non-null  object
#  2   ANONYMOUS_1          14095 non-null  int64
#  3   YEAR                 14095 non-null  int64
#  4   SAMPLE_TRANSFER_DAY  14095 non-null  int64
#  5   ANONYMOUS_2          14095 non-null  int64
#  6   AG                   14095 non-null  int64
#  7   AL                   14095 non-null  int64
#  8   B                    14095 non-null  int64
#  9   BA                   14095 non-null  int64
#  10  BE                   14095 non-null  int64
#  11  CA                   14095 non-null  int64
#  12  CD                   12701 non-null  float64
#  13  CO                   14095 non-null  int64
#  14  CR                   14095 non-null  int64
# ...

# %%
oil_info = pd.read_csv('C:/k_digital/source/data/open/data_info.csv')
oil_info
# Out:
#            Feature Name                       Description
# 0   COMPONENT_ARBITRARY  샘플 오일 관련 부품 (Component 4종, 비식별화)
# 1           ANONYMOUS_1             무명 Feautre 1. 수치형 데이터
# 2                  YEAR               오일 샘플 및 진단 해 (Year)
# 3   SAMPLE_TRANSFER_DAY    오일 샘플링 후 진단 기관으로 이동한 기간 (Days)
# 4           ANONYMOUS_2             무명 Feautre 2. 수치형 데이터
# 5                    AG              원소기호 AG - Silver 함유량
# 6                    AL           원소기호 AL - Aluminium 함유량
# 7                     B                원소기호 B - Boron 함유량
# 8                    BA             원소기호 BA -  Barium 함유량
# 9                    BE           원소기호 BE - Beryllium 함유량
# 10                   CA             원소기호 CA - Calcium 함유량
# 11                   CD             원소기호 CD - Cadmium 함유량
# 12                   CO              원소기호 CO - Cobolt 함유량
# 13                   CR            원소기호 CR - Chromium 함유량
# 14                   CU              원소기호 CU - Copper 함유량
# ...

# %%
oil.iloc[430, :]
# Out:
# ID                     TRAIN_00430
# COMPONENT_ARBITRARY     COMPONENT4
# ANONYMOUS_1                   2271
# YEAR                          2009
# SAMPLE_TRANSFER_DAY              8
# ANONYMOUS_2                    200
# AG                               0
# AL                               1
# B                                1
# BA                               0
# BE                               0
# CA                              16
# CD                             NaN
# CO                               0
# CR                               0
# CU                              20
# FH2O                           NaN
# FNOX                           NaN
# FOPTIMETHGLY                   NaN
# FOXID                          NaN
# FSO4                           NaN
# FTBN                           NaN
# FE                               5
# FUEL                           NaN
# H2O                            0.0
# K                              0.0
# LI                               0
# ...

# %%
# jsonl 파일 예시(각 줄마다 json 형식)
{ "id": "101", "name": "aaa", "buy_list" : ["lemon", "orange"]}
{ "id": "102", "name": "bbb"}
{ "id": "103", "name": "ccc", "buy_list" : ["melon"], "age" : 35}
{ "id": "104", "name": "ddd", "age" : 29}
# Out:
# {'id': '104', 'name': 'ddd', 'age': 29}

# %%
# !pip install jsonlines

# %%
import jsonlines

# id 정보를 모아서 저장하는 예시
id_list = []

# open 내의 디렉토리 및 파일 이름에 유의
with jsonlines.open('customer.jsonl') as f:
    for line in f:
    	id_list.append(line['id'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15840/1598553596.py in <module>
#       5
#       6 # open 내의 디렉토리 및 파일 이름에 유의
# ----> 7 with jsonlines.open('customer.jsonl') as f:
#       8     for line in f:
#       9         id_list.append(line['id'])
#
# C:\Ananconda3\lib\site-packages\jsonlines\jsonlines.py in open(file, mode, loads, dumps, compact, sort_keys, flush)
#     625     cls = Reader if mode == "r" else Writer
#     626     encoding = "utf-8-sig" if mode == "r" else "utf-8"
# --> 627     fp = builtins.open(file, mode=mode + "t", encoding=encoding)
#     628     kwargs = dict(
#     629         loads=loads,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'customer.jsonl'
